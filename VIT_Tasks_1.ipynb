# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Task 1

# %%
rand = np.random.randint(0,100,size=(10,5))
rand
# Out:
# array([[57, 75, 32, 99, 78],
#        [60,  8, 34, 68, 32],
#        [11, 81, 87, 77, 72],
#        [17, 90, 35, 32, 89],
#        [39, 19, 51, 89, 27],
#        [60, 47, 45, 26, 27],
#        [92, 68, 87,  6, 45],
#        [ 3, 84, 90, 89, 19],
#        [90,  4,  1, 35, 62],
#        [96, 37, 84, 58,  7]])

# %%
df = pd.DataFrame(rand)
df
# Out:
#     0   1   2   3   4
# 0  57  75  32  99  78
# 1  60   8  34  68  32
# 2  11  81  87  77  72
# 3  17  90  35  32  89
# 4  39  19  51  89  27
# 5  60  47  45  26  27
# 6  92  68  87   6  45
# 7   3  84  90  89  19
# 8  90   4   1  35  62
# 9  96  37  84  58   7

# %% [markdown]
# Task 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       10 non-null     int64
#  1   1       10 non-null     int64
#  2   2       10 non-null     int64
#  3   3       10 non-null     int64
#  4   4       10 non-null     int64
# dtypes: int64(5)
# memory usage: 528.0 bytes

# %% [markdown]
# Task 3

# %%
df.describe()
# Out:
#                0          1          2         3          4
# count  10.000000  10.000000  10.000000  10.00000  10.000000
# mean   52.500000  51.300000  54.600000  57.90000  45.800000
# std    34.329288  32.775499  30.757835  31.61733  27.836028
# min     3.000000   4.000000   1.000000   6.00000   7.000000
# 25%    22.500000  23.500000  34.250000  32.75000  27.000000
# 50%    58.500000  57.500000  48.000000  63.00000  38.500000
# 75%    82.500000  79.500000  86.250000  86.00000  69.500000
# max    96.000000  90.000000  90.000000  99.00000  89.000000

# %% [markdown]
# Task 4

# %%
df.loc[3]
# Out:
# 0    17
# 1    90
# 2    35
# 3    32
# 4    89
# Name: 3, dtype: int64

# %% [markdown]
# Task 5

# %%
df.isnull().any()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
